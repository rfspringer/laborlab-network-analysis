# %%
import pandas as pd

# %%
oecd = pd.read_csv('./data/oecd.csv')
ind = pd.read_csv('./data/IND1950.csv')

# %%
ind['Label']
# Out:
# 0                                NIU
# 1                        Agriculture
# 2                           Forestry
# 3                          Fisheries
# 4                       Metal mining
#                    ...
# 143    Federal public administration
# 144      State public administration
# 145      Local public administration
# 146                  Nonclassifiable
# 147            Industry not reported
# Name: Label, Length: 148, dtype: object

# %%
# get unique industry/sectors from 'From industry / sector' and 'To industry / sector'
# get ind1950 and codes
# make dict from oecd ind descriptions to cps ind descriptions
# add ind1950

# %%
oecd_industries = pd.unique(oecd[['From industry / sector', 'To industry / sector']].values.ravel())
cps_industries = ind['Label'].tolist()

# %%
oecd_industries
# Out:
# array(['Activities of households as employers; undifferentiated goods- and services-producing activities of households for own use',
#        'Construction',
#        'Manufacturing nec; repair and installation of machinery and equipment',
#        'Mining support service activities',
#        'Water supply; sewerage, waste management and remediation activities',
#        'Fishing and aquaculture',
#        'Electricity, gas, steam and air conditioning supply',
#        'Computer, electronic and optical equipment',
#        'Other transport equipment',
#        'Textiles, textile products, leather and footwear',
#        'Human health and social work activities',
#        'Machinery and equipment, nec', 'Electrical equipment',
#        'Pharmaceuticals, medicinal chemical and botanical products',
#        'Chemical and chemical products', 'Rubber and plastics products',
#        'Coke and refined petroleum products',
#        'Paper products and printing',
# ...

# %%
cps_industries
# Out:
# ['NIU',
#  'Agriculture',
#  'Forestry',
#  'Fisheries',
#  'Metal mining',
#  'Coal mining',
#  'Crude petroleum and natural gas extraction',
#  'Nonmetallic mining and quarrying, except fuel',
#  'Construction',
#  'Logging',
#  'Sawmills, planing mills, and millwork',
#  'Misc wood products',
#  'Furniture and fixtures',
#  'Glass and glass products',
#  'Cement, concrete, gypsum and plaster products',
#  'Structural clay products',
#  'Pottery and related products',
#  'Miscellaneous nonmetallic mineral and stone products',
#  'Blast furnaces, steel works, and rolling mills',
#  'Other primary iron and steel industries',
#  'Primary nonferrous industries',
#  'Fabricated steel products',
#  'Fabricated nonferrous metal products',
#  'Not specified metal industries',
#  'Agricultural machinery and tractors',
#  'Office and store machines and devices',
#  'Miscellaneous machinery',
#  'Electrical machinery, equipment, and supplies',
#  'Motor vehicles and motor vehicle equipment',
# ...

# %%
oecd_isic_mapping_chatgpt = {
    'Activities of households as employers; undifferentiated goods- and services-producing activities of households for own use': ['T'],
    'Construction': ['F'],
    'Manufacturing nec; repair and installation of machinery and equipment': ['C32', 'C33'],
    'Mining support service activities': ['B09'],
    'Water supply; sewerage, waste management and remediation activities': ['E'],
    'Fishing and aquaculture': ['A03'],
    'Electricity, gas, steam and air conditioning supply': ['D'],
    'Computer, electronic and optical equipment': ['C26'],
    'Other transport equipment': ['C30'],
    'Textiles, textile products, leather and footwear': ['C13', 'C14', 'C15'],
    'Human health and social work activities': ['Q'],
    'Machinery and equipment, nec': ['C28'],
    'Electrical equipment': ['C27'],
    'Pharmaceuticals, medicinal chemical and botanical products': ['C21'],
    'Chemical and chemical products': ['C20'],
    'Rubber and plastics products': ['C22'],
    'Coke and refined petroleum products': ['C19'],
    'Paper products and printing': ['C17', 'C18'],
    'Food products, beverages and tobacco': ['C10', 'C11', 'C12'],


    
    'Mining and quarrying, non-energy producing products': ['B08'],
    'Mining and quarrying, energy producing products': ['B05', 'B06', 'B07'],


    
    'Motor vehicles, trailers and semi-trailers': ['C29'],
    'Basic metals': ['C24'],
    'Other non-metallic mineral products': ['C23'],
    'Wood and products of wood and cork': ['C16'],
    'Arts, entertainment and recreation': ['R'],
    'Land transport and transport via pipelines': ['H49'],
    'Fabricated metal products': ['C25'],
    'Water transport': ['H50'],
    'Education': ['P'],
    'Agriculture, hunting, forestry': ['A01', 'A02'],
    'Output at basic prices': None,  # This is an economic measure, not an ISIC category
    'Imports (cross border)': None,  # This is an economic measure, not an ISIC category
    'Taxes less subsidies on intermediate and final products (paid in domestic agencies, includes duty on imported products)': None,  # This is an economic measure, not an ISIC category
    'Taxes less subsidies on intermediate and final products (paid in foreign countries)': None,  # This is an economic measure, not an ISIC category
    'Exports (cross border)': None,  # This is an economic measure, not an ISIC category
    'Direct purchases by non-residents (exports)': None,  # This is an economic measure, not an ISIC category
    'Value added at basic prices': None,  # This is an economic measure, not an ISIC category
    'Direct purchases abroad by residents (imports)': None,  # This is an economic measure, not an ISIC category
    'Gross Fixed Capital Formation': None,  # This is an economic measure, not an ISIC category
    'Final consumption expenditure of general government': None,  # This is an economic measure, not an ISIC category
    'Changes in inventories': None,  # This is an economic measure, not an ISIC category
    'Other service activities': ['S'],
    'Air transport': ['H51'],
    'Postal and courier activities': ['H53'],
    'Publishing, audiovisual and broadcasting activities': ['J58', 'J59', 'J60'],
    'Accommodation and food service activities': ['I'],
    'Warehousing and support activities for transportation': ['H52'],
    'Telecommunications': ['J61'],
    'IT and other information services': ['J62', 'J63'],
    'Public administration and defence; compulsory social security': ['O'],
    'Real estate activities': ['L'],
    'Administrative and support services': ['N'],
    'Professional, scientific and technical activities': ['M'],
    'Financial and insurance activities': ['K'],
    'Total intermediate consumption at purchasers’ prices': None,  # This is an economic measure, not an ISIC category
    'Wholesale and retail trade; repair of motor vehicles': ['G'],
    'Total': None,  # This is an economic measure, not an ISIC category
    'Imports content of exports shares': None,  # This is an economic measure, not an ISIC category
    'Final consumption expenditure of non-profit institutions serving households': None,  # This is an economic measure, not an ISIC category
    'Final consumption expenditure of households': None  # This is an economic measure, not an ISIC category
}

# %%
# use chatgpt to get isic rev 4 codes from each oecd in-out- the industry codes 
# chat gpt make a dictionary from industry descriptions to isic codes from the pdf
#
- codes above get isic rev 4 codes from oecd input output tables
- convert isic codes to naics codes
- convert naics codes to cps codes
- make a map from ind1990 to isic rev 4 and from isic rev 4 to ind1990
- download/ get ind1990 codes for the stuff
    - might have to redownload data and recalculate/rerun with ind1990 as the code

# oecd tables are from isic rev 4
# isic rev 4 (from oecd in out) to naics to cps 2020 to cps 1990

# isic rev 4 to NAICS
# NAICS to CPS 2020
# CPS 2020 to CPS 1990

# and also
# CPS 1990 to CPS 2020
# CPS 2020 to NAICS
# NAICS to ISIC rev 4
# make bidirectional map- from isic rev 4 codes to naics (most 

# ntoe: current codes are under 2017 census classification scheme

# %%
# concordance package: https://rdrr.io/github/insongkim/concordance/f/README.md has ISIC rev 4

# %%
# OECD to ISIC rev 4 
# use chat gpt or similar to parse into dictionary from industry code to ISIC division and vice versa
# https://file.notion.so/f/f/7e518ebe-cc43-4d38-808a-e40e81eeaa29/99a5a23d-b4de-4fc4-8e70-3aaeb94335ee/IOT_Industry_Sector.pdf?table=block&id=106a6e69-893d-8091-bdbc-d8b261e62535&spaceId=7e518ebe-cc43-4d38-808a-e40e81eeaa29&expirationTimestamp=1729123200000&signature=6OzToUZxBIoafBOjsaqvCmN_JHh1ngmVHvHAr8Y-CbM&downloadName=IOT_Industry_Sector.pdf

# %%
# ISIC Rev 4 to NAICS 2017

# %%
# NAICS 2017 to current ind codes https://www2.census.gov/programs-surveys/cps/methodology/Industry%20Codes.pdf
# the problem here is that we want to be able to compare stuff over time

# %%
# generally: lots of crosswalk stuff here!

# %%
# IND 1990 to SIC 1987 https://www2.census.gov/programs-surveys/demo/guidance/industry-occupation/1990-census-sic-codes.pdf
# SIC 1987 to NAICS 2022

# NAICS to isic rev 4 ????

# %%
# isic rev 4 to NAICS 2017, 2012 or 2007 https://unstats.un.org/unsd/classifications/Econ/isic
