# %%
import pandas as pd
from collections import defaultdict
import os
import pickle
from tqdm import tqdm

# %%
def add_to_data_graph(df):
    industry_state_dict = defaultdict(list)
    nodes = []
    for index, row in df.iterrows():
        # if row['AGE'] >= 25 and row['AGE'] < 64 and row['is_full_time_full_year'] and row['winsor99']:    # filter by age above 18
        id = str(row['YEAR']) + '-' + str(row['SERIAL']) + '-' + str(row['PERNUM'])
        state_industry = str(row['STATECENSUS']) + '-' + str(row['IND'])
            
        entry = {'stateXindustry': state_industry, 'id': id, 'labor_income': row['labor_income'], 'capital_income': row['capital_income'], 'age': row['AGE'], 'full_time_full_year': row['is_full_time_full_year'], 'bottom_99': row['winsor99']}
        industry_state_dict[state_industry].append(entry)

    return industry_state_dict


def process_data(df, dir, filename, save=False):
    industry_state_dict = add_to_data_graph(df)
    
    if save:
        dict_filename = os.path.join(dir, f"{filename}.pkl")
        with open(dict_filename, 'wb') as f:
            pickle.dump(industry_state_dict, f)

    return industry_state_dict

# %%
df = pd.read_csv('./data/cps_data/2000.csv')

# %%
process_data(df, './data/cps_data/', '2000_dict', save=True)
# Out:
# Processing IPUMS data (might take a while)
#
# Saving results...
# defaultdict(list,
#             {'11-651': [{'stateXindustry': '11-651',
#                'id': '2001-3-1',
#                'labor_income': 37108.625,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-651',
#                'id': '2001-352-1',
#                'labor_income': 35624.28,
#                'capital_income': 219.90296296296293},
#               {'stateXindustry': '11-651',
#                'id': '2001-352-2',
#                'labor_income': 32655.59,
#                'capital_income': 219.90296296296293},
#               {'stateXindustry': '11-651',
#                'id': '2001-1424-1',
#                'labor_income': 44530.35,
#                'capital_income': 4.398059259259258},
#               {'stateXindustry': '11-651',
#                'id': '2001-1525-2',
#                'labor_income': 51952.075,
#                'capital_income': 2097.9850091660005}],
#              '11-732': [{'stateXindustry': '11-732',
#                'id': '2001-4-1',
#                'labor_income': 106872.84,
#                'capital_income': 7237.813349320543},
#               {'stateXindustry': '11-732',
#                'id': '2001-15-1',
#                'labor_income': 28202.555,
#                'capital_income': 7314.542081001864},
#               {'stateXindustry': '11-732',
#                'id': '2001-305-2',
#                'labor_income': 22265.175,
#                'capital_income': 7991.273674074074},
#               {'stateXindustry': '11-732',
#                'id': '2001-334-3',
#                'labor_income': 29686.9,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-732',
#                'id': '2001-491-1',
#                'labor_income': 24505.051605,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-732',
#                'id': '2001-595-1',
#                'labor_income': 46014.695,
#                'capital_income': 164.92722222222218},
#               {'stateXindustry': '11-732',
#                'id': '2001-1272-2',
#                'labor_income': 43046.005,
#                'capital_income': 10.995148148148148},
#               {'stateXindustry': '11-732',
#                'id': '2001-1730-2',
#                'labor_income': 96482.425,
#                'capital_income': 2.199029629629629}],
#              '11-601': [{'stateXindustry': '11-601',
#                'id': '2001-5-1',
#                'labor_income': 106872.84,
#                'capital_income': 65.97088888888887},
#               {'stateXindustry': '11-601',
#                'id': '2001-119-1',
#                'labor_income': 105388.495,
#                'capital_income': 769.6603703703702},
#               {'stateXindustry': '11-601',
#                'id': '2001-140-1',
#                'labor_income': 50467.73,
#                'capital_income': 3848.301851851851},
#               {'stateXindustry': '11-601',
#                'id': '2001-169-1',
#                'labor_income': 28202.555,
#                'capital_income': 1319.4177777777777},
#               {'stateXindustry': '11-601',
#                'id': '2001-391-1',
#                'labor_income': 53436.42,
#                'capital_income': 3298.5444444444443},
#               {'stateXindustry': '11-601',
#                'id': '2001-402-1',
#                'labor_income': 27478.19464,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-601',
#                'id': '2001-509-1',
#                'labor_income': 57889.455,
#                'capital_income': 323.5263016253664},
#               {'stateXindustry': '11-601',
#                'id': '2001-598-3',
#                'labor_income': 35322.957965,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-601',
#                'id': '2001-1019-2',
#                'labor_income': 15437.187999999998,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-601',
#                'id': '2001-1256-3',
#                'labor_income': 11874.76,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-601',
#                'id': '2001-1321-2',
#                'labor_income': 28202.555,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-601',
#                'id': '2001-1357-1',
#                'labor_income': 29686.9,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-601',
#                'id': '2001-1491-1',
#                'labor_income': 40077.315,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-601',
#                'id': '2001-1597-2',
#                'labor_income': 29686.9,
#                'capital_income': 4.398059259259258},
#               {'stateXindustry': '11-601',
#                'id': '2001-1645-3',
#                'labor_income': 37108.625,
#                'capital_income': 54.97574074074073},
#               {'stateXindustry': '11-601',
#                'id': '2001-1676-1',
#                'labor_income': 46014.695,
#                'capital_income': 120.9466296296296},
#               {'stateXindustry': '11-601',
#                'id': '2001-1690-1',
#                'labor_income': 96482.425,
#                'capital_income': 445.2232434441741},
#               {'stateXindustry': '11-601',
#                'id': '2001-1690-2',
#                'labor_income': 35624.28,
#                'capital_income': 445.2232434441741},
#               {'stateXindustry': '11-601',
#                'id': '2001-1714-2',
#                'labor_income': 62342.49,
#                'capital_income': 4735.317630802024}],
#              '11-842': [{'stateXindustry': '11-842',
#                'id': '2001-5-2',
#                'labor_income': 65311.17999999999,
#                'capital_income': 65.97088888888887},
#               {'stateXindustry': '11-842',
#                'id': '2001-8-1',
#                'labor_income': 48983.385,
#                'capital_income': 439.80592592592586},
#               {'stateXindustry': '11-842',
#                'id': '2001-30-1',
#                'labor_income': 52694.2475,
#                'capital_income': 52.77671111111111},
#               {'stateXindustry': '11-842',
#                'id': '2001-71-1',
#                'labor_income': 34139.935,
#                'capital_income': 65.97088888888887},
#               {'stateXindustry': '11-842',
#                'id': '2001-119-3',
#                'labor_income': 47499.04,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-842',
#                'id': '2001-176-2',
#                'labor_income': 63084.6625,
#                'capital_income': 398.02436296296287},
#               {'stateXindustry': '11-842',
#                'id': '2001-232-1',
#                'labor_income': 48092.778,
#                'capital_income': 32.98544444444443},
#               {'stateXindustry': '11-842',
#                'id': '2001-331-1',
#                'labor_income': 92029.39,
#                'capital_income': 2487.1025111111107},
#               {'stateXindustry': '11-842',
#                'id': '2001-393-2',
#                'labor_income': 48241.2125,
#                'capital_income': 659.7088888888887},
#               {'stateXindustry': '11-842',
#                'id': '2001-454-1',
#                'labor_income': 41561.66,
#                'capital_income': 153.93207407407405},
#               {'stateXindustry': '11-842',
#                'id': '2001-595-2',
#                'labor_income': 44530.35,
#                'capital_income': 109.95148148148148},
#               {'stateXindustry': '11-842',
#                'id': '2001-598-2',
#                'labor_income': 51952.075,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-842',
#                'id': '2001-616-2',
#                'labor_income': 48983.385,
#                'capital_income': 19127.52358673061},
#               {'stateXindustry': '11-842',
#                'id': '2001-630-1',
#                'labor_income': 65088.52825,
#                'capital_income': 4469.235045616839},
#               {'stateXindustry': '11-842',
#                'id': '2001-645-1',
#                'labor_income': 48983.385,
#                'capital_income': 43.980592592592586},
#               {'stateXindustry': '11-842',
#                'id': '2001-645-2',
#                'labor_income': 51952.075,
#                'capital_income': 43.980592592592586},
#               {'stateXindustry': '11-842',
#                'id': '2001-722-2',
#                'labor_income': 47499.04,
#                'capital_income': 3357.285430162536},
#               {'stateXindustry': '11-842',
#                'id': '2001-852-1',
#                'labor_income': 56405.11,
#                'capital_income': 1776.8159407407406},
#               {'stateXindustry': '11-842',
#                'id': '2001-852-2',
#                'labor_income': 57889.455,
#                'capital_income': 9902.792218113003},
#               {'stateXindustry': '11-842',
#                'id': '2001-855-3',
#                'labor_income': 50467.73,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-842',
#                'id': '2001-1103-1',
#                'labor_income': 111325.875,
#                'capital_income': 36268.91278148478},
#               {'stateXindustry': '11-842',
#                'id': '2001-1143-1',
#                'labor_income': 51209.9025,
#                'capital_income': 508.149868371969},
#               {'stateXindustry': '11-842',
#                'id': '2001-1186-2',
#                'labor_income': 33843.066,
#                'capital_income': 626.7234444444443},
#               {'stateXindustry': '11-842',
#                'id': '2001-1248-3',
#                'labor_income': 38592.97,
#                'capital_income': 43.980592592592586},
#               {'stateXindustry': '11-842',
#                'id': '2001-1304-1',
#                'labor_income': 35624.28,
#                'capital_income': 2.199029629629629},
#               {'stateXindustry': '11-842',
#                'id': '2001-1315-1',
#                'labor_income': 53733.289,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-842',
#                'id': '2001-1317-2',
#                'labor_income': 40077.315,
#                'capital_income': 57.17477037037036},
#               {'stateXindustry': '11-842',
#                'id': '2001-1336-1',
#                'labor_income': 55217.634,
#                'capital_income': 5328.248792592592},
#               {'stateXindustry': '11-842',
#                'id': '2001-1336-2',
#                'labor_income': 71248.56,
#                'capital_income': 5328.248792592592},
#               {'stateXindustry': '11-842',
#                'id': '2001-1338-1',
#                'labor_income': 46014.695,
#                'capital_income': 21.990296296296293},
#               {'stateXindustry': '11-842',
#                'id': '2001-1384-1',
#                'labor_income': 66795.525,
#                'capital_income': 2199.0296296296297},
#               {'stateXindustry': '11-842',
#                'id': '2001-1384-2',
#                'labor_income': 59373.8,
#                'capital_income': 2199.0296296296297},
#               {'stateXindustry': '11-842',
#                'id': '2001-1403-1',
#                'labor_income': 43046.005,
#                'capital_income': 151.73304444444443},
#               {'stateXindustry': '11-842',
#                'id': '2001-1441-1',
#                'labor_income': 29686.9,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-842',
#                'id': '2001-1467-2',
#                'labor_income': 35624.28,
#                'capital_income': 219.90296296296293},
#               {'stateXindustry': '11-842',
#                'id': '2001-1515-2',
#                'labor_income': 40819.4875,
#                'capital_income': 5759.098086888348},
#               {'stateXindustry': '11-842',
#                'id': '2001-1553-2',
#                'labor_income': 47499.04,
#                'capital_income': 2964.29194074074},
#               {'stateXindustry': '11-842',
#                'id': '2001-1566-1',
#                'labor_income': 55217.634,
#                'capital_income': 1776.8159407407406},
#               {'stateXindustry': '11-842',
#                'id': '2001-1588-1',
#                'labor_income': 38296.101,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-842',
#                'id': '2001-1590-2',
#                'labor_income': 37108.625,
#                'capital_income': 384.8301851851851},
#               {'stateXindustry': '11-842',
#                'id': '2001-1700-1',
#                'labor_income': 41561.66,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-842',
#                'id': '2001-1708-1',
#                'labor_income': 48983.385,
#                'capital_income': 647.0526032507328},
#               {'stateXindustry': '11-842',
#                'id': '2001-1709-1',
#                'labor_income': 59373.8,
#                'capital_income': 30385.132035685318},
#               {'stateXindustry': '11-842',
#                'id': '2001-1709-2',
#                'labor_income': 59373.8,
#                'capital_income': 3298.5444444444443},
#               {'stateXindustry': '11-842',
#                'id': '2001-1723-2',
#                'labor_income': 63826.835,
#                'capital_income': 4456.214891766587},
#               {'stateXindustry': '11-842',
#                'id': '2001-1728-2',
#                'labor_income': 62342.49,
#                'capital_income': 1776.8159407407406},
#               {'stateXindustry': '11-842',
#                'id': '2001-1731-1',
#                'labor_income': 106872.84,
#                'capital_income': 5559.146903703703},
#               {'stateXindustry': '11-842',
#                'id': '2001-1731-2',
#                'labor_income': 75701.595,
#                'capital_income': 5559.146903703703}],
#              '11-612': [{'stateXindustry': '11-612',
#                'id': '2001-7-2',
#                'labor_income': 94998.08,
#                'capital_income': 252.88840740740736},
#               {'stateXindustry': '11-612',
#                'id': '2001-149-1',
#                'labor_income': 37850.7975,
#                'capital_income': 1740.239275246469},
#               {'stateXindustry': '11-612',
#                'id': '2001-603-2',
#                'labor_income': 29093.162,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-612',
#                'id': '2001-1090-2',
#                'labor_income': 64569.0075,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-612',
#                'id': '2001-1107-1',
#                'labor_income': 44530.35,
#                'capital_income': 109.95148148148148},
#               {'stateXindustry': '11-612',
#                'id': '2001-1126-2',
#                'labor_income': 59373.8,
#                'capital_income': 5497.574074074073},
#               {'stateXindustry': '11-612',
#                'id': '2001-1129-1',
#                'labor_income': 44530.35,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-612',
#                'id': '2001-1140-1',
#                'labor_income': 31171.245,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-612',
#                'id': '2001-1329-1',
#                'labor_income': 81638.97499999999,
#                'capital_income': 109.95148148148148},
#               {'stateXindustry': '11-612',
#                'id': '2001-1420-3',
#                'labor_income': 33397.7625,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-612',
#                'id': '2001-1572-1',
#                'labor_income': 60858.145,
#                'capital_income': 2211.3695081268315},
#               {'stateXindustry': '11-612',
#                'id': '2001-1573-1',
#                'labor_income': 30429.0725,
#                'capital_income': 4.398059259259258},
#               {'stateXindustry': '11-612',
#                'id': '2001-1580-2',
#                'labor_income': 29686.9,
#                'capital_income': 74.76700740740739},
#               {'stateXindustry': '11-612',
#                'id': '2001-1693-3',
#                'labor_income': 51952.075,
#                'capital_income': 2584.888138022915},
#               {'stateXindustry': '11-612',
#                'id': '2001-1702-2',
#                'labor_income': 127680.38821,
#                'capital_income': 22762.04495379696}],
#              '11-420': [{'stateXindustry': '11-420',
#                'id': '2001-8-2',
#                'labor_income': 66795.525,
#                'capital_income': 439.80592592592586},
#               {'stateXindustry': '11-420',
#                'id': '2001-58-1',
#                'labor_income': 40077.315,
#                'capital_income': 1111.8546933120172},
#               {'stateXindustry': '11-420',
#                'id': '2001-1426-1',
#                'labor_income': 22265.175,
#                'capital_income': 54.97574074074073}],
#              '11-910': [{'stateXindustry': '11-910',
#                'id': '2001-25-2',
#                'labor_income': 111325.875,
#                'capital_income': 1099.5148148148148},
#               {'stateXindustry': '11-910',
#                'id': '2001-61-2',
#                'labor_income': 74217.25,
#                'capital_income': 79.16506666666665},
#               {'stateXindustry': '11-910',
#                'id': '2001-104-2',
#                'labor_income': 31171.245,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-910',
#                'id': '2001-240-1',
#                'labor_income': 63826.835,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-910',
#                'id': '2001-344-1',
#                'labor_income': 33397.7625,
#                'capital_income': 15.393207407407406},
#               {'stateXindustry': '11-910',
#                'id': '2001-477-1',
#                'labor_income': 71248.56,
#                'capital_income': 2355.6511644018124},
#               {'stateXindustry': '11-910',
#                'id': '2001-481-1',
#                'labor_income': 40077.315,
#                'capital_income': 219.90296296296293},
#               {'stateXindustry': '11-910',
#                'id': '2001-482-1',
#                'labor_income': 38778.513125,
#                'capital_income': 21.990296296296293},
#               {'stateXindustry': '11-910',
#                'id': '2001-646-1',
#                'labor_income': 69891.86867,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-910',
#                'id': '2001-792-1',
#                'labor_income': 92029.39,
#                'capital_income': 798.7856476951772},
#               {'stateXindustry': '11-910',
#                'id': '2001-803-2',
#                'labor_income': 53436.42,
#                'capital_income': 9805.41399426444},
#               {'stateXindustry': '11-910',
#                'id': '2001-1144-1',
#                'labor_income': 56405.10999999999,
#                'capital_income': 329.8544444444444},
#               {'stateXindustry': '11-910',
#                'id': '2001-1144-2',
#                'labor_income': 80154.62999999999,
#                'capital_income': 131.94177777777773},
#               {'stateXindustry': '11-910',
#                'id': '2001-1385-2',
#                'labor_income': 96482.425,
#                'capital_income': 105.5534222222222},
#               {'stateXindustry': '11-910',
#                'id': '2001-1611-1',
#                'labor_income': 45374.942305,
#                'capital_income': 439.80592592592586},
#               {'stateXindustry': '11-910',
#                'id': '2001-1674-1',
#                'labor_income': 41561.66,
#                'capital_income': 1099.5148148148148},
#               {'stateXindustry': '11-910',
#                'id': '2001-1711-1',
#                'labor_income': 33397.7625,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-910',
#                'id': '2001-1737-1',
#                'labor_income': 81638.97499999999,
#                'capital_income': 2130.8597111111108}],
#              '11-831': [{'stateXindustry': '11-831',
#                'id': '2001-29-1',
#                'labor_income': 68279.87,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-47-1',
#                'labor_income': 41561.66,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-52-1',
#                'labor_income': 74217.25,
#                'capital_income': 6339.802422222221},
#               {'stateXindustry': '11-831',
#                'id': '2001-56-2',
#                'labor_income': 74217.25,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-102-1',
#                'labor_income': 41561.66,
#                'capital_income': 6597.0888888888885},
#               {'stateXindustry': '11-831',
#                'id': '2001-155-2',
#                'labor_income': 43506.15195,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-189-2',
#                'labor_income': 37108.625,
#                'capital_income': 219.90296296296293},
#               {'stateXindustry': '11-831',
#                'id': '2001-228-2',
#                'labor_income': 50467.73,
#                'capital_income': 32.98544444444443},
#               {'stateXindustry': '11-831',
#                'id': '2001-269-2',
#                'labor_income': 59373.8,
#                'capital_income': 13.194177777777776},
#               {'stateXindustry': '11-831',
#                'id': '2001-292-2',
#                'labor_income': 65311.17999999999,
#                'capital_income': 252.88840740740736},
#               {'stateXindustry': '11-831',
#                'id': '2001-316-1',
#                'labor_income': 43491.3085,
#                'capital_income': 244.09228888888887},
#               {'stateXindustry': '11-831',
#                'id': '2001-338-3',
#                'labor_income': 14130.9644,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-423-1',
#                'labor_income': 51952.075,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-441-2',
#                'labor_income': 8906.07,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-445-2',
#                'labor_income': 66795.525,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-488-1',
#                'labor_income': 110510.969595,
#                'capital_income': 54.97574074074073},
#               {'stateXindustry': '11-831',
#                'id': '2001-511-1',
#                'labor_income': 34139.935,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-513-1',
#                'labor_income': 63826.835,
#                'capital_income': 659.7088888888887},
#               {'stateXindustry': '11-831',
#                'id': '2001-551-1',
#                'labor_income': 34139.935,
#                'capital_income': 81.36409629629627},
#               {'stateXindustry': '11-831',
#                'id': '2001-559-1',
#                'labor_income': 35624.28,
#                'capital_income': 549.7574074074074},
#               {'stateXindustry': '11-831',
#                'id': '2001-565-2',
#                'labor_income': 40077.315,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-688-1',
#                'labor_income': 59587.54568,
#                'capital_income': 556.3544962962961},
#               {'stateXindustry': '11-831',
#                'id': '2001-726-1',
#                'labor_income': 73586.403375,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-729-1',
#                'labor_income': 25233.865,
#                'capital_income': 43.980592592592586},
#               {'stateXindustry': '11-831',
#                'id': '2001-733-1',
#                'labor_income': 74217.25,
#                'capital_income': 329.8544444444444},
#               {'stateXindustry': '11-831',
#                'id': '2001-843-1',
#                'labor_income': 81638.97499999999,
#                'capital_income': 307.8641481481481},
#               {'stateXindustry': '11-831',
#                'id': '2001-904-2',
#                'labor_income': 25233.865,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-930-2',
#                'labor_income': 44530.35,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-956-2',
#                'labor_income': 57889.455,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-1056-1',
#                'labor_income': 22265.175,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-1057-1',
#                'labor_income': 126816.49941999998,
#                'capital_income': 81.36409629629627},
#               {'stateXindustry': '11-831',
#                'id': '2001-1093-1',
#                'labor_income': 25233.865,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-1110-1',
#                'labor_income': 35505.5324,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-1115-2',
#                'labor_income': 51952.075,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-1165-2',
#                'labor_income': 20780.83,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-1273-2',
#                'labor_income': 17812.14,
#                'capital_income': 1759.2237037037034},
#               {'stateXindustry': '11-831',
#                'id': '2001-1310-1',
#                'labor_income': 44530.35,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-1385-1',
#                'labor_income': 59373.8,
#                'capital_income': 57.0482075139888},
#               {'stateXindustry': '11-831',
#                'id': '2001-1413-2',
#                'labor_income': 59373.8,
#                'capital_income': 7066.953493205436},
#               {'stateXindustry': '11-831',
#                'id': '2001-1425-2',
#                'labor_income': 95026.282555,
#                'capital_income': 1617.2043584865442},
#               {'stateXindustry': '11-831',
#                'id': '2001-1453-1',
#                'labor_income': 90545.045,
#                'capital_income': 2355.6511644018124},
#               {'stateXindustry': '11-831',
#                'id': '2001-1486-1',
#                'labor_income': 28202.555,
#                'capital_income': 8.796118518518517},
#               {'stateXindustry': '11-831',
#                'id': '2001-1491-2',
#                'labor_income': 53436.42,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-831',
#                'id': '2001-1509-2',
#                'labor_income': 38592.97,
#                'capital_income': 32.98544444444443},
#               {'stateXindustry': '11-831',
#                'id': '2001-1517-2',
#                'labor_income': 23749.52,
#                'capital_income': 304.7000767386091},
#               {'stateXindustry': '11-831',
#                'id': '2001-1537-1',
#                'labor_income': 25233.865,
#                'capital_income': 6687.786995843325},
#               {'stateXindustry': '11-831',
#                'id': '2001-1573-2',
#                'labor_income': 56405.11,
#                'capital_income': 715.7038878886185},
#               {'stateXindustry': '11-831',
#                'id': '2001-1595-2',
#                'labor_income': 32655.59,
#                'capital_income': 1991.73549123368},
#               {'stateXindustry': '11-831',
#                'id': '2001-1603-2',
#                'labor_income': 25233.865,
#                'capital_income': 123.14565925925923},
#               {'stateXindustry': '11-831',
#                'id': '2001-1611-2',
#                'labor_income': 26718.21,
#                'capital_income': 439.80592592592586},
#               {'stateXindustry': '11-831',
#                'id': '2001-1684-2',
#                'labor_income': 51952.075,
#                'capital_income': 329.8544444444444},
#               {'stateXindustry': '11-831',
#                'id': '2001-1729-2',
#                'labor_income': 37850.7975,
#                'capital_income': 108.36944577671196}],
#              '11-60': [{'stateXindustry': '11-60',
#                'id': '2001-31-2',
#                'labor_income': 37108.625,
#                'capital_income': 6533.807460698108},
#               {'stateXindustry': '11-60',
#                'id': '2001-86-2',
#                'labor_income': 112810.22,
#                'capital_income': 1598.6945407407406},
#               {'stateXindustry': '11-60',
#                'id': '2001-92-2',
#                'labor_income': 59373.8,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-111-1',
#                'labor_income': 68279.87,
#                'capital_income': 4687.967302158273},
#               {'stateXindustry': '11-60',
#                'id': '2001-181-2',
#                'labor_income': 110732.137,
#                'capital_income': 127.54371851851847},
#               {'stateXindustry': '11-60',
#                'id': '2001-183-2',
#                'labor_income': 47499.04,
#                'capital_income': 81.36409629629627},
#               {'stateXindustry': '11-60',
#                'id': '2001-206-1',
#                'labor_income': 66795.525,
#                'capital_income': 32.98544444444443},
#               {'stateXindustry': '11-60',
#                'id': '2001-218-1',
#                'labor_income': 53436.42,
#                'capital_income': 21.990296296296293},
#               {'stateXindustry': '11-60',
#                'id': '2001-229-2',
#                'labor_income': 92771.5625,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-251-1',
#                'labor_income': 31171.245,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-253-1',
#                'labor_income': 92029.39,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-257-2',
#                'labor_income': 41561.66,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-278-1',
#                'labor_income': 17812.14,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-312-2',
#                'labor_income': 29686.9,
#                'capital_income': 925.791474074074},
#               {'stateXindustry': '11-60',
#                'id': '2001-314-1',
#                'labor_income': 43788.1775,
#                'capital_income': 183.53871751824815},
#               {'stateXindustry': '11-60',
#                'id': '2001-320-2',
#                'labor_income': 96482.425,
#                'capital_income': 4491.399365840662},
#               {'stateXindustry': '11-60',
#                'id': '2001-366-3',
#                'labor_income': 59373.8,
#                'capital_income': 1268.840096296296},
#               {'stateXindustry': '11-60',
#                'id': '2001-372-2',
#                'labor_income': 43046.005,
#                'capital_income': 1319.4177777777777},
#               {'stateXindustry': '11-60',
#                'id': '2001-375-1',
#                'labor_income': 44530.35,
#                'capital_income': 54.97574074074073},
#               {'stateXindustry': '11-60',
#                'id': '2001-392-2',
#                'labor_income': 59373.8,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-479-2',
#                'labor_income': 54920.765,
#                'capital_income': 2990.047482014388},
#               {'stateXindustry': '11-60',
#                'id': '2001-533-1',
#                'labor_income': 78670.28499999999,
#                'capital_income': 26.388355555555552},
#               {'stateXindustry': '11-60',
#                'id': '2001-558-1',
#                'labor_income': 74217.25,
#                'capital_income': 219.90296296296293},
#               {'stateXindustry': '11-60',
#                'id': '2001-588-1',
#                'labor_income': 66795.525,
#                'capital_income': 32.98544444444443},
#               {'stateXindustry': '11-60',
#                'id': '2001-597-1',
#                'labor_income': 73007.508825,
#                'capital_income': 19.79126666666666},
#               {'stateXindustry': '11-60',
#                'id': '2001-665-1',
#                'labor_income': 28944.7275,
#                'capital_income': 15.393207407407406},
#               {'stateXindustry': '11-60',
#                'id': '2001-685-1',
#                'labor_income': 47499.04,
#                'capital_income': 376.3030127364774},
#               {'stateXindustry': '11-60',
#                'id': '2001-723-1',
#                'labor_income': 41561.66,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-749-1',
#                'labor_income': 114941.73941999998,
#                'capital_income': 371.63600740740736},
#               {'stateXindustry': '11-60',
#                'id': '2001-930-1',
#                'labor_income': 22265.175,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1019-1',
#                'labor_income': 31171.245,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1101-2',
#                'labor_income': 29686.9,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1109-1',
#                'labor_income': 59373.8,
#                'capital_income': 371.63600740740736},
#               {'stateXindustry': '11-60',
#                'id': '2001-1116-1',
#                'labor_income': 74217.25,
#                'capital_income': 888.4079703703703},
#               {'stateXindustry': '11-60',
#                'id': '2001-1147-1',
#                'labor_income': 35624.28,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1167-1',
#                'labor_income': 34139.935,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1182-1',
#                'labor_income': 31171.245,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1207-2',
#                'labor_income': 40737.848525,
#                'capital_income': 13.194177777777776},
#               {'stateXindustry': '11-60',
#                'id': '2001-1208-1',
#                'labor_income': 34883.591844999995,
#                'capital_income': 35.18447407407407},
#               {'stateXindustry': '11-60',
#                'id': '2001-1221-2',
#                'labor_income': 93513.735,
#                'capital_income': 888.4079703703703},
#               {'stateXindustry': '11-60',
#                'id': '2001-1298-1',
#                'labor_income': 44530.35,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1313-1',
#                'labor_income': 109841.52999999998,
#                'capital_income': 109.95148148148148},
#               {'stateXindustry': '11-60',
#                'id': '2001-1316-3',
#                'labor_income': 103904.15,
#                'capital_income': 490.921499547029},
#               {'stateXindustry': '11-60',
#                'id': '2001-1321-1',
#                'labor_income': 43046.005,
#                'capital_income': 9807.672148148147},
#               {'stateXindustry': '11-60',
#                'id': '2001-1325-2',
#                'labor_income': 89060.7,
#                'capital_income': 1297.4274814814812},
#               {'stateXindustry': '11-60',
#                'id': '2001-1328-2',
#                'labor_income': 56405.11,
#                'capital_income': 879.6118518518517},
#               {'stateXindustry': '11-60',
#                'id': '2001-1334-1',
#                'labor_income': 26718.21,
#                'capital_income': 21.990296296296293},
#               {'stateXindustry': '11-60',
#                'id': '2001-1359-1',
#                'labor_income': 25233.865,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1359-2',
#                'labor_income': 44530.35,
#                'capital_income': 21669.2700729927},
#               {'stateXindustry': '11-60',
#                'id': '2001-1409-1',
#                'labor_income': 26618.758885,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1417-2',
#                'labor_income': 56405.11,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1428-2',
#                'labor_income': 17813.624345,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1440-2',
#                'labor_income': 51952.075,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1446-2',
#                'labor_income': 56405.11,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1452-1',
#                'labor_income': 89060.7,
#                'capital_income': 3439.1874185984548},
#               {'stateXindustry': '11-60',
#                'id': '2001-1475-2',
#                'labor_income': 14843.45,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1499-4',
#                'labor_income': 32655.59,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1509-1',
#                'labor_income': 44530.35,
#                'capital_income': 32.98544444444443},
#               {'stateXindustry': '11-60',
#                'id': '2001-1518-2',
#                'labor_income': 37108.625,
#                'capital_income': 32.98544444444443},
#               {'stateXindustry': '11-60',
#                'id': '2001-1562-1',
#                'labor_income': 53287.98549999999,
#                'capital_income': 2135.7482014388493},
#               {'stateXindustry': '11-60',
#                'id': '2001-1563-2',
#                'labor_income': 54178.5925,
#                'capital_income': 15.393207407407406},
#               {'stateXindustry': '11-60',
#                'id': '2001-1566-2',
#                'labor_income': 32358.721,
#                'capital_income': 1776.8159407407406},
#               {'stateXindustry': '11-60',
#                'id': '2001-1575-1',
#                'labor_income': 59373.8,
#                'capital_income': 184.71848888888888},
#               {'stateXindustry': '11-60',
#                'id': '2001-1577-1',
#                'labor_income': 23155.782,
#                'capital_income': 6.597088888888888},
#               {'stateXindustry': '11-60',
#                'id': '2001-1595-1',
#                'labor_income': 104646.3225,
#                'capital_income': 1991.73549123368},
#               {'stateXindustry': '11-60',
#                'id': '2001-1600-3',
#                'labor_income': 39516.23259,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1608-1',
#                'labor_income': 59373.8,
#                'capital_income': 76.96603703703703},
#               {'stateXindustry': '11-60',
#                'id': '2001-1610-2',
#                'labor_income': 78760.830045,
#                'capital_income': 252.88840740740736},
#               {'stateXindustry': '11-60',
#                'id': '2001-1619-1',
#                'labor_income': 86654.57675499999,
#                'capital_income': 27.40761381454447},
#               {'stateXindustry': '11-60',
#                'id': '2001-1645-1',
#                'labor_income': 48983.385,
#                'capital_income': 2688.827883826272},
#               {'stateXindustry': '11-60',
#                'id': '2001-1678-1',
#                'labor_income': 44530.35,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1695-1',
#                'labor_income': 20780.83,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-60',
#                'id': '2001-1698-1',
#                'labor_income': 59373.8,
#                'capital_income': 0.0}],
#              '11-892': [{'stateXindustry': '11-892',
#                'id': '2001-32-1',
#                'labor_income': 44530.35,
#                'capital_income': 10898.643970157207},
#               {'stateXindustry': '11-892',
#                'id': '2001-323-1',
#                'labor_income': 103904.15,
#                'capital_income': 55664.9621015324},
#               {'stateXindustry': '11-892',
#                'id': '2001-329-1',
#                'labor_income': 35624.28,
#                'capital_income': 2071.058761470824},
#               {'stateXindustry': '11-892',
#                'id': '2001-699-1',
#                'labor_income': 103167.91487999998,
#                'capital_income': 274.8787037037037},
#               {'stateXindustry': '11-892',
#                'id': '2001-712-2',
#                'labor_income': 44530.35,
#                'capital_income': 27984.629581668},
#               {'stateXindustry': '11-892',
#                'id': '2001-719-1',
#                'labor_income': 35624.28,
#                'capital_income': 109.95148148148148}],
#              '11-451': [{'stateXindustry': '11-451',
#                'id': '2001-34-1',
#                'labor_income': 51952.075,
#                'capital_income': 1521.7285037037034}],
#              '11-641': [{'stateXindustry': '11-641',
#                'id': '2001-49-1',
#                'labor_income': 32655.59,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-641',
#                'id': '2001-178-1',
#                'labor_income': 39271.315665,
#                'capital_income': 109.95148148148148},
#               {'stateXindustry': '11-641',
#                'id': '2001-333-3',
#                'labor_income': 20780.83,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-641',
#                'id': '2001-356-1',
#                'labor_income': 90545.045,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-641',
#                'id': '2001-504-2',
#                'labor_income': 40746.754595,
#                'capital_income': 180.3204296296296},
#               {'stateXindustry': '11-641',
#                'id': '2001-603-1',
#                'labor_income': 24046.389,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-641',
#                'id': '2001-644-1',
#                'labor_income': 50467.73,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-641',
#                'id': '2001-1248-1',
#                'labor_income': 41561.66,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-641',
#                'id': '2001-1397-2',
#                'labor_income': 51952.075,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-641',
#                'id': '2001-1439-1',
#                'labor_income': 46014.695,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-641',
#                'id': '2001-1462-1',
#                'labor_income': 44530.35,
#                'capital_income': 0.0}],
#              '11-850': [{'stateXindustry': '11-850',
#                'id': '2001-50-1',
#                'labor_income': 35624.28,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-850',
#                'id': '2001-116-1',
#                'labor_income': 65014.311,
#                'capital_income': 290.271911111111},
#               {'stateXindustry': '11-850',
#                'id': '2001-143-1',
#                'labor_income': 71248.56,
#                'capital_income': 334.12594084732206},
#               {'stateXindustry': '11-850',
#                'id': '2001-200-1',
#                'labor_income': 103904.15,
#                'capital_income': 5984.050053290701},
#               {'stateXindustry': '11-850',
#                'id': '2001-419-2',
#                'labor_income': 32655.59,
#                'capital_income': 81.36409629629627},
#               {'stateXindustry': '11-850',
#                'id': '2001-497-1',
#                'labor_income': 59373.8,
#                'capital_income': 2748.7870370370365},
#               {'stateXindustry': '11-850',
#                'id': '2001-497-2',
#                'labor_income': 44530.35,
#                'capital_income': 2748.7870370370365},
#               {'stateXindustry': '11-850',
#                'id': '2001-502-2',
#                'labor_income': 28549.89173,
#                'capital_income': 46.17962222222221},
#               {'stateXindustry': '11-850',
#                'id': '2001-523-1',
#                'labor_income': 89060.7,
#                'capital_income': 67532.82765921725},
#               {'stateXindustry': '11-850',
#                'id': '2001-534-1',
#                'labor_income': 51655.206,
#                'capital_income': 32.98544444444443},
#               {'stateXindustry': '11-850',
#                'id': '2001-535-1',
#                'labor_income': 63826.835,
#                'capital_income': 549.7574074074074},
#               {'stateXindustry': '11-850',
#                'id': '2001-540-2',
#                'labor_income': 87576.355,
#                'capital_income': 3785.020423661072},
#               {'stateXindustry': '11-850',
#                'id': '2001-559-2',
#                'labor_income': 29686.9,
#                'capital_income': 549.7574074074074},
#               {'stateXindustry': '11-850',
#                'id': '2001-592-2',
#                'labor_income': 28944.7275,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-850',
#                'id': '2001-602-1',
#                'labor_income': 20255.37187,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-850',
#                'id': '2001-653-2',
#                'labor_income': 28024.4336,
#                'capital_income': 0.0},
#               {'stateXindustry': '11-850',
#                'id': '2001-749-2',
#                'labor_income': 32655.59,
#                'capital_income': 277.0777333333333},
#               {'stateXindustry': '11-850',
#                'id': '2001-1332-1',
#                'labor_income': 34139.935,
#                'capital_income': 326.6903730349054},
#               {'stateXindustry': '11-850',
#                'id': '2001-1429-1',
#                'labor_income': 59373.8,
#                'capital_income': 20154.72354948041},
#               {'stateXindustry': '11-850',
#                'id': '2001-1471-2',
#                'labor_income': 71248.56,
#                'capital_income': 439.80592592592586},
#               {'stateXindustry': '11-850',
#                'id': '2001-1512-1',
#                'labor_income': 63084.6625,
#                'capital_income': 0.0}],
#              '11-932': [{'stateXindustry': '11-932',
#                'id': '2001-51-1',
#                'labor_income': 62342.49,
#                'capital_income': 439.80592592592586},
#               {'stateXindustry': '11-932',
#                'id': '2001-336-1',
#                'labor_income': 44530.35,
#                'capital_income': 3480.4785504929387},
# ...
#                'labor_income': 17812.14,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-12270-2',
#                'labor_income': 59373.8,
#                'capital_income': 52.77671111111111},
#               {'stateXindustry': '21-832',
#                'id': '2001-12360-2',
#                'labor_income': 44530.35,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-12416-1',
#                'labor_income': 37108.625,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-12418-3',
#                'labor_income': 40077.315,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-12502-1',
#                'labor_income': 17812.14,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-12568-1',
#                'labor_income': 29686.9,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-12658-1',
#                'labor_income': 47499.04,
#                'capital_income': 41.78156296296296},
#               {'stateXindustry': '21-832',
#                'id': '2001-12907-1',
#                'labor_income': 47499.04,
#                'capital_income': 228.69908148148144},
#               {'stateXindustry': '21-832',
#                'id': '2001-13252-1',
#                'labor_income': 92029.39,
#                'capital_income': 633.3205333333332},
#               {'stateXindustry': '21-832',
#                'id': '2001-13288-3',
#                'labor_income': 37108.625,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-13293-1',
#                'labor_income': 23749.52,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-13455-2',
#                'labor_income': 59373.8,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-13660-1',
#                'labor_income': 40077.315,
#                'capital_income': 1482.14597037037},
#               {'stateXindustry': '21-832',
#                'id': '2001-13783-1',
#                'labor_income': 59373.8,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-14032-3',
#                'labor_income': 51952.075,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-14121-2',
#                'labor_income': 86092.01,
#                'capital_income': 87.96118518518517},
#               {'stateXindustry': '21-832',
#                'id': '2001-14143-1',
#                'labor_income': 115778.91,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-14149-1',
#                'labor_income': 38592.97,
#                'capital_income': 57.17477037037036},
#               {'stateXindustry': '21-832',
#                'id': '2001-14160-1',
#                'labor_income': 44530.35,
#                'capital_income': 279.54570903277374},
#               {'stateXindustry': '21-832',
#                'id': '2001-14302-1',
#                'labor_income': 34116.18547999999,
#                'capital_income': 5.417317518248174},
#               {'stateXindustry': '21-832',
#                'id': '2001-14476-2',
#                'labor_income': 34139.935,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-14519-1',
#                'labor_income': 35178.9765,
#                'capital_income': 219.90296296296293},
#               {'stateXindustry': '21-832',
#                'id': '2001-14600-1',
#                'labor_income': 37049.2512,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-14691-1',
#                'labor_income': 29686.9,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-14734-1',
#                'labor_income': 21612.0632,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-14878-2',
#                'labor_income': 89060.7,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-14896-1',
#                'labor_income': 51952.075,
#                'capital_income': 490.3836074074073},
#               {'stateXindustry': '21-832',
#                'id': '2001-14917-3',
#                'labor_income': 28852.69811,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-832',
#                'id': '2001-15137-2',
#                'labor_income': 22265.175,
#                'capital_income': 219.90296296296293},
#               {'stateXindustry': '21-832',
#                'id': '2001-15247-2',
#                'labor_income': 66498.65599999999,
#                'capital_income': 74.76700740740739},
#               {'stateXindustry': '21-832',
#                'id': '2001-15405-2',
#                'labor_income': 24551.0663,
#                'capital_income': 8242.524847742632},
#               {'stateXindustry': '21-832',
#                'id': '2001-15419-1',
#                'labor_income': 35030.542,
#                'capital_income': 0.0}],
#              '21-623': [{'stateXindustry': '21-623',
#                'id': '2001-10601-1',
#                'labor_income': 34139.935,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-623',
#                'id': '2001-10927-1',
#                'labor_income': 37108.625,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-623',
#                'id': '2001-11225-5',
#                'labor_income': 16209.047399999998,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-623',
#                'id': '2001-11381-2',
#                'labor_income': 11874.76,
#                'capital_income': 10.995148148148148},
#               {'stateXindustry': '21-623',
#                'id': '2001-11727-1',
#                'labor_income': 59373.8,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-623',
#                'id': '2001-11817-2',
#                'labor_income': 33843.066,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-623',
#                'id': '2001-12007-2',
#                'labor_income': 92029.39,
#                'capital_income': 13.194177777777776},
#               {'stateXindustry': '21-623',
#                'id': '2001-12084-1',
#                'labor_income': 25233.865,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-623',
#                'id': '2001-12377-3',
#                'labor_income': 60703.77312,
#                'capital_income': 427.1496402877698},
#               {'stateXindustry': '21-623',
#                'id': '2001-13122-1',
#                'labor_income': 89060.7,
#                'capital_income': 74.76700740740739},
#               {'stateXindustry': '21-623',
#                'id': '2001-13367-1',
#                'labor_income': 38592.97,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-623',
#                'id': '2001-14094-1',
#                'labor_income': 29686.9,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-623',
#                'id': '2001-14136-2',
#                'labor_income': 28499.423999999995,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-623',
#                'id': '2001-14348-1',
#                'labor_income': 71248.56,
#                'capital_income': 2535.481162962963}],
#              '21-880': [{'stateXindustry': '21-880',
#                'id': '2001-10604-1',
#                'labor_income': 50467.73,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-880',
#                'id': '2001-10668-1',
#                'labor_income': 23749.52,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-880',
#                'id': '2001-11152-1',
#                'labor_income': 53436.42,
#                'capital_income': 3298.5444444444443},
#               {'stateXindustry': '21-880',
#                'id': '2001-12131-2',
#                'labor_income': 11355.23925,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-880',
#                'id': '2001-12229-1',
#                'labor_income': 37108.625,
#                'capital_income': 105.5534222222222},
#               {'stateXindustry': '21-880',
#                'id': '2001-13224-1',
#                'labor_income': 59373.8,
#                'capital_income': 178.1214},
#               {'stateXindustry': '21-880',
#                'id': '2001-13952-1',
#                'labor_income': 106872.84,
#                'capital_income': 1954.510191100453},
#               {'stateXindustry': '21-880',
#                'id': '2001-13952-2',
#                'labor_income': 72732.905,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-880',
#                'id': '2001-14303-2',
#                'labor_income': 62342.49,
#                'capital_income': 10.995148148148148},
#               {'stateXindustry': '21-880',
#                'id': '2001-14456-1',
#                'labor_income': 25233.865,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-880',
#                'id': '2001-14491-1',
#                'labor_income': 29686.9,
#                'capital_income': 219.90296296296293},
#               {'stateXindustry': '21-880',
#                'id': '2001-14491-2',
#                'labor_income': 34139.935,
#                'capital_income': 81.36409629629627},
#               {'stateXindustry': '21-880',
#                'id': '2001-14526-1',
#                'labor_income': 37111.59369,
#                'capital_income': 457.3981629629629}],
#              '21-311': [{'stateXindustry': '21-311',
#                'id': '2001-10607-1',
#                'labor_income': 25233.865,
#                'capital_income': 4446.43791111111}],
#              '21-772': [{'stateXindustry': '21-772',
#                'id': '2001-10614-1',
#                'labor_income': 42452.267,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-772',
#                'id': '2001-10962-1',
#                'labor_income': 32655.59,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-772',
#                'id': '2001-11069-1',
#                'labor_income': 32655.59,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-772',
#                'id': '2001-11514-1',
#                'labor_income': 81638.97499999999,
#                'capital_income': 33775.275770050626},
#               {'stateXindustry': '21-772',
#                'id': '2001-11711-2',
#                'labor_income': 37108.625,
#                'capital_income': 219.90296296296293},
#               {'stateXindustry': '21-772',
#                'id': '2001-12132-2',
#                'labor_income': 34733.672999999995,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-772',
#                'id': '2001-13023-2',
#                'labor_income': 29686.9,
#                'capital_income': 13.194177777777776},
#               {'stateXindustry': '21-772',
#                'id': '2001-13160-3',
#                'labor_income': 29686.9,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-772',
#                'id': '2001-13270-1',
#                'labor_income': 31171.245,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-772',
#                'id': '2001-13414-1',
#                'labor_income': 37108.625,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-772',
#                'id': '2001-13467-3',
#                'labor_income': 46014.695,
#                'capital_income': 76.96603703703703},
#               {'stateXindustry': '21-772',
#                'id': '2001-14231-2',
#                'labor_income': 38592.97,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-772',
#                'id': '2001-14356-3',
#                'labor_income': 22265.175,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-772',
#                'id': '2001-14963-1',
#                'labor_income': 35921.149,
#                'capital_income': 65.97088888888887},
#               {'stateXindustry': '21-772',
#                'id': '2001-15259-1',
#                'labor_income': 13359.105,
#                'capital_income': 854.2992805755396}],
#              '21-371': [{'stateXindustry': '21-371',
#                'id': '2001-10615-1',
#                'labor_income': 40077.315,
#                'capital_income': 556.3544962962961},
#               {'stateXindustry': '21-371',
#                'id': '2001-11240-2',
#                'labor_income': 59373.8,
#                'capital_income': 2012.6500032507329},
#               {'stateXindustry': '21-371',
#                'id': '2001-14287-1',
#                'labor_income': 63826.835,
#                'capital_income': 17970.73907940314},
#               {'stateXindustry': '21-371',
#                'id': '2001-14552-1',
#                'labor_income': 47499.04,
#                'capital_income': 10.995148148148148},
#               {'stateXindustry': '21-371',
#                'id': '2001-14978-1',
#                'labor_income': 118747.6,
#                'capital_income': 769.6603703703702}],
#              '21-642': [{'stateXindustry': '21-642',
#                'id': '2001-10635-1',
#                'labor_income': 32109.35104,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-642',
#                'id': '2001-10683-1',
#                'labor_income': 117263.255,
#                'capital_income': 197.2482116706635},
#               {'stateXindustry': '21-642',
#                'id': '2001-11153-4',
#                'labor_income': 34139.935,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-642',
#                'id': '2001-12131-4',
#                'labor_income': 19296.485,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-642',
#                'id': '2001-12402-1',
#                'labor_income': 80154.62999999999,
#                'capital_income': 852.5274005861977},
#               {'stateXindustry': '21-642',
#                'id': '2001-12440-1',
#                'labor_income': 89060.7,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-642',
#                'id': '2001-12497-2',
#                'labor_income': 99451.115,
#                'capital_income': 329.8544444444444},
#               {'stateXindustry': '21-642',
#                'id': '2001-13126-1',
#                'labor_income': 29686.9,
#                'capital_income': 54.97574074074073},
#               {'stateXindustry': '21-642',
#                'id': '2001-13243-2',
#                'labor_income': 37108.625,
#                'capital_income': 2.199029629629629},
#               {'stateXindustry': '21-642',
#                'id': '2001-13556-1',
#                'labor_income': 19296.485,
#                'capital_income': 26.388355555555552},
#               {'stateXindustry': '21-642',
#                'id': '2001-13578-5',
#                'labor_income': 66795.525,
#                'capital_income': 659.7088888888887},
#               {'stateXindustry': '21-642',
#                'id': '2001-13829-1',
#                'labor_income': 28336.14605,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-642',
#                'id': '2001-13982-1',
#                'labor_income': 35490.68895,
#                'capital_income': 0.0},
#               {'stateXindustry': '21-642',
#                'id': '2001-15349-2',
#                'labor_income': 64836.18959999999,
#                'capital_income': 83.12015592859046}],
#              ...})

# %%
# for each year dictionary
# run through and process data into a dictionary
# pickle each dictionary and save them 
MIN_YEAR = 1975
MAX_YEAR = 2022
for year in tqdm(range(MIN_YEAR, MAX_YEAR + 1), desc="Processing years"):
    df = pd.read_csv(f'./data/cps_data/{year}.csv')
    process_data(df, './data/cps_data/', f'{year}_dict', save=True)
# Out:
# Processing years: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [03:07<00:00,  3.91s/it]
